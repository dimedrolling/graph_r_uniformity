# %%
from modules.graph_functions import *
import matplotlib.pyplot as plt
import networkx as nx

# %%
adj_mat = adjacency_matrix_binomial(14)
G = generate_random_graph(14, adj_mat)
generate_random_state(G,4)
G.plot_graph()

# %%
G.set_rules(spread,disconnect)
print(G)
G.print_nodes()
# Out:
# : nodes(14, starred(10); was changed? True; Simplified? False
# 0(1), neighbours:3, 4, 5, 6, 7, 10, 11,
# 1(1), neighbours:3, 4, 5, 6, 8, 9, 11, 12, 13,
# 2(1), neighbours:3, 4, 10, 11,
# 3(0), neighbours:0, 1, 2, 9, 12, 13, wire2,
# 4(1), neighbours:0, 1, 2, 11,
# 5(0), neighbours:0, 1, 6, 8, 9, 10, 13, wire0,
# 6(1), neighbours:0, 1, 5, 8, 9, 12,
# 7(1), neighbours:0,
# 8(0), neighbours:1, 5, 6, 9, 11, 13, wire1,
# 9(1), neighbours:1, 3, 5, 6, 8, 12,
# 10(1), neighbours:0, 2, 5,
# 11(0), neighbours:0, 1, 2, 4, 8, wire3,
# 12(1), neighbours:1, 3, 6, 9, 13,
# 13(1), neighbours:1, 3, 5, 8, 12,

# %%
G.simplify_step()
G.print_nodes()
# Out:
# 0(0), neighbours:1, 3, 5, 7, 8, 9, 10, 11, 12, wire0,
# 1(1), neighbours:0, 2, 3, 6,
# 2(0), neighbours:1, 3, 6, 7, 8, 10, 12, wire2,
# 3(0), neighbours:0, 1, 2, 8, 10, 11, 12, wire3,
# 4(1), neighbours:
# 5(1), neighbours:0,
# 6(0), neighbours:1, 2, 10, 11, wire1,
# 7(1), neighbours:0, 2, 9,
# 8(1), neighbours:0, 2, 3,
# 9(1), neighbours:0, 7,
# 10(1), neighbours:0, 2, 3, 6, 13,
# 11(1), neighbours:0, 3, 6, 12,
# 12(1), neighbours:0, 2, 3, 11,
# 13(1), neighbours:10,

# %%
G.simplify_step()
G.plot_graph()
